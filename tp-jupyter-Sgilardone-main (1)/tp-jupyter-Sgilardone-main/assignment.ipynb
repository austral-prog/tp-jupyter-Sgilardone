# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).

# %% [markdown]
# ---

# %% [markdown]
# # [EXERCISE 1]
# ## Santiago Gilardone sgilardone@mail.austral.edu.ar
# ![image.png](attachment:8ede747b-e729-480a-8269-3c0ae06e3f53.png)
# ### This is my dog Tommy, he was adopted two years ago. He was rescued from a shady breeding shelter.

# %% [markdown]
# # [EXERCISE 2]

# %%
#Write a function rectangle_area(width, height) that takes the width and height of a rectangle as input and returns its area.
def rectangle_area():
    width = int(input("Insert rectangle width here: ")) 
    height = int(input("Insert rectangle height here: "))
    print("Rectangle area:", height * width)

# %% [markdown]
# # [EXERCISE 3]

# %%
#Use your created function to calculate the area of a rectangle with width 3 and height 4. Another of width 5 and height 10, and another of width 8 and height 2. Show your results in the same cell with a description of each result. Similar to this example:
#`The area of a rectangle with width 3 and height 4 is 12.`
def rectangle_area():
    width1 = int(input("Insert first rectangle width: ")) 
    height1 = int(input("Insert first rectangle height: "))

    width2 = int(input("Insert second rectangle width: ")) 
    height2 = int(input("Insert second rectangle height: "))

    width3 = int(input("Insert third rectangle width: ")) 
    height3 = int(input("Insert third rectangle height: "))

    result1 = height1 * width1
    result2 = height2 * width2
    result3 = height3 * width3

    print("\nRectangle areas:")
    print(f"1st: {result1} (width={width1}, height={height1})")
    print(f"2nd: {result2} (width={width2}, height={height2})")
    print(f"3rd: {result3} (width={width3}, height={height3})")

# %% [markdown]
# # [EXERCISE 5]
#
# 1. CREATE A NEW CELL BELOW THIS ONE AND ADD A MARKDOWN TITLE (HEADING 1) WITH THE TEXT "[EXERCISE 5]"
# 2. Create a new cell below to solve the following actions in python:
#
#     `Create a variable called a and assign it the value 3. Create a variable called b and assign it the value 7`
#
# 3. With the variables created perform the 4 basic operations (sum, substraction, multiplication and division). Add a markdown title with the operation name and print the result.
#
# 4. DO NOT KEEP THE CELL WITH THESE INSTRUCTIONS.

# %% [markdown]
# # [Exercise 5]

# %% [markdown]
# # Sum

# %%
a=3
b=7
print(a+b)
# Out:
# 10

# %% [markdown]
# # Substraction

# %%
a=3
b=7
print(a-b)
# Out:
# -4

# %% [markdown]
# # Multiplication

# %%
a=3
b=7
print(a*b)
# Out:
# 21

# %% [markdown]
# # Division

# %%
a=3
b=7
print(a/b)
# Out:
# 0.42857142857142855
